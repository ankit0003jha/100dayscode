# %% [markdown]
# ![Adobe%20Scan%20Aug%2010,%202021_1.jpg](attachment:Adobe%20Scan%20Aug%2010,%202021_1.jpg)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2010,%202021_2.jpg](attachment:Adobe%20Scan%20Aug%2010,%202021_2.jpg)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2010,%202021_3.jpg](attachment:Adobe%20Scan%20Aug%2010,%202021_3.jpg)

# %% [markdown]
# ![Linkedlist.png](attachment:Linkedlist.png)

# %% [markdown]
# ## Delete or remove Node from beginning.

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.ref = None
    
class Linkedlist:
    def __init__(self):
        self.head = None
        
    def Print_data(self):
        if self.head is None:
            print(self.head)
            print("linked-list is empty")
        else:
            n = self.head
            while n is not None:
                print(n.data , "--->",end=" ")
                n = n.ref
    
    def add_begin(self,data):
        new_node = Node(data)
        new_node.ref = self.head
        self.head = new_node
        
    def add_end(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
            n.ref = new_node
    
    def add_after_inbetween(self,data,x):
        n = self.head
        while n is not None:
            if n.data == x:
                break
            n=n.ref
            
        if n is None:
            print("Item is not present")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
            
    def remove_begin(self):
        if self.head is None:
            print("empty")
        else:
            n = self.head
            n1 = n.ref
            self.head = n1

LL1 = Linkedlist()
LL1.add_begin(10)
LL1.add_begin(20)
LL1.add_begin(30)
LL1.add_end(13)
LL1.add_after_inbetween(14,10)
LL1.remove_begin()
LL1.Print_data()
# Out:
# 20 ---> 10 ---> 14 ---> 13 --->

# %% [markdown]
# ## Delete or remove Node from the end of linked-list.

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.ref = None
    
class Linkedlist:
    def __init__(self):
        self.head = None
        
    def Print_data(self):
        if self.head is None:
            print(self.head)
            print("linked-list is empty")
        else:
            n = self.head
            while n is not None:
                print(n.data , "--->",end=" ")
                n = n.ref
    
    def add_begin(self,data):
        new_node = Node(data)
        new_node.ref = self.head
        self.head = new_node
        
    def add_end(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
            n.ref = new_node
    
    def add_after_inbetween(self,data,x):
        n = self.head
        while n is not None:
            if n.data == x:
                break
            n=n.ref
            
        if n is None:
            print("Item is not present")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
    
    def remove_end(self):
        if self.head is None:
            print("empty")
        else:
            n = self.head
            while n.ref.ref is not None:
                n = n.ref
            n.ref = None
        

LL1 = Linkedlist()
LL1.add_begin(10)
LL1.add_begin(20)
LL1.add_begin(30)
LL1.add_end(13)
LL1.add_after_inbetween(14,10)
#LL1.remove_end()
LL1.Print_data()
# Out:
# 30 ---> 20 ---> 10 ---> 14 ---> 13 --->

# %% [markdown]
# ## Delete or remove by the value provided.

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.ref = None
    
class Linkedlist:
    def __init__(self):
        self.head = None
        
    def Print_data(self):
        if self.head is None:
            print(self.head)
            print("linked-list is empty")
        else:
            n = self.head
            while n is not None:
                print(n.data , "--->",end=" ")
                n = n.ref
    
    def add_begin(self,data):
        new_node = Node(data)
        new_node.ref = self.head
        self.head = new_node
        
    def add_end(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
            n.ref = new_node
    
    def add_after_inbetween(self,data,x):
        n = self.head
        while n is not None:
            if n.data == x:
                break
            n=n.ref
            
        if n is None:
            print("Item is not present")
        else:
            new_node = Node(data)
            new_node.ref = n.ref
            n.ref = new_node
            
    def remove_any(self,x):
        if self.head is None:
            print("empty LL")
        else:
            n = self.head
            while n.ref.data != x:
                n = n.ref
            if n.ref is None:
                print("Node is note present")
            else:
                n.ref = n.ref.ref
        

LL1 = Linkedlist()
LL1.add_begin(10)
LL1.add_begin(20)
LL1.add_begin(30)
LL1.add_end(13)
LL1.add_after_inbetween(14,10)
LL1.remove_any(10)
LL1.Print_data()
# Out:
# 30 ---> 20 ---> 14 ---> 13 --->
