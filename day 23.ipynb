# %% [markdown]
# ![Adobe%20Scan%20Aug%2013,%202021_9.jpg](attachment:Adobe%20Scan%20Aug%2013,%202021_9.jpg)

# %% [markdown]
# ![Queue.png](attachment:Queue.png)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2013,%202021_10.jpg](attachment:Adobe%20Scan%20Aug%2013,%202021_10.jpg)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2013,%202021_11.jpg](attachment:Adobe%20Scan%20Aug%2013,%202021_11.jpg)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2013,%202021_12.jpg](attachment:Adobe%20Scan%20Aug%2013,%202021_12.jpg)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2013,%202021_13.jpg](attachment:Adobe%20Scan%20Aug%2013,%202021_13.jpg)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2013,%202021_14.jpg](attachment:Adobe%20Scan%20Aug%2013,%202021_14.jpg)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2013,%202021_15.jpg](attachment:Adobe%20Scan%20Aug%2013,%202021_15.jpg)

# %% [markdown]
# ![Queue.png](attachment:Queue.png)

# %%
Queue = []

def Enqueue():
    if len(Queue) == n:
        print("\nERROR --> queue is full, we cant perform Enqueue operation anymore\n")
    else:
        element = input("\nEnter the element you have to Enqueue into this queue\n")
        Queue.append(element)
    
def Dequeue():
    if not Queue:
        print("\nERROR --> Queue is empty\n")
    else:
        Queue.pop(0)

n = int(input("Please enter the length of the queue\n"))     
while True:
    print("\nSelect the opeartion you have to perform \n 1-Enqueue \n 2-Dequeue \n 3-quit \n")
    choice = int(input("\n"))
    if choice == 1:
        Enqueue()
    elif choice == 2:
        Dequeue()
    elif choice == 3:
        print("\nYour final queue is here\n" , Queue)
        break
    else:
        print("\nERROR --> please enter the correct opration\n")
# Out:
# Please enter the length of the queue
# 2
#
# Select the opeartion you have to perform
#  1-Enqueue
#  2-Dequeue
#  3-quit
#
#
# 1
#
# Enter the element you have to Enqueue into this queue
# 22
#
# Select the opeartion you have to perform
#  1-Enqueue
#  2-Dequeue
#  3-quit
#
#
# 1
#
# Enter the element you have to Enqueue into this queue
# 33
#
# Select the opeartion you have to perform
#  1-Enqueue
#  2-Dequeue
#  3-quit
#
#
# 1
#
# ERROR --> queue is full, we cant perform Enqueue operation anymore
#
#
# Select the opeartion you have to perform
#  1-Enqueue
#  2-Dequeue
#  3-quit
#
#
# 2
#
# Select the opeartion you have to perform
#  1-Enqueue
#  2-Dequeue
#  3-quit
#
#
# 3
#
# Your final queue is here
#  ['33']
