# %% [markdown]
# ![Adobe%20Scan%20Aug%2023,%202021_6.jpg](attachment:Adobe%20Scan%20Aug%2023,%202021_6.jpg)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2023,%202021_7.jpg](attachment:Adobe%20Scan%20Aug%2023,%202021_7.jpg)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2023,%202021_8.jpg](attachment:Adobe%20Scan%20Aug%2023,%202021_8.jpg)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2023,%202021_9.jpg](attachment:Adobe%20Scan%20Aug%2023,%202021_9.jpg)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2023,%202021_10.jpg](attachment:Adobe%20Scan%20Aug%2023,%202021_10.jpg)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2023,%202021_11.jpg](attachment:Adobe%20Scan%20Aug%2023,%202021_11.jpg)

# %% [markdown]
# ![MinHeapAndMaxHeap.png](attachment:MinHeapAndMaxHeap.png)
