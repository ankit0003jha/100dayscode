# %% [markdown]
# ![Adobe%20Scan%20Aug%2011,%202021_1.jpg](attachment:Adobe%20Scan%20Aug%2011,%202021_1.jpg)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2011,%202021_2.jpg](attachment:Adobe%20Scan%20Aug%2011,%202021_2.jpg)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2011,%202021_3.jpg](attachment:Adobe%20Scan%20Aug%2011,%202021_3.jpg)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2011,%202021_4.jpg](attachment:Adobe%20Scan%20Aug%2011,%202021_4.jpg)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2011,%202021_5.jpg](attachment:Adobe%20Scan%20Aug%2011,%202021_5.jpg)

# %% [markdown]
# ![Adobe%20Scan%20Aug%2011,%202021_6.jpg](attachment:Adobe%20Scan%20Aug%2011,%202021_6.jpg)

# %% [markdown]
# ![DLL1.png](attachment:DLL1.png)

# %% [markdown]
# ## Trasversing doubly-linked list in forward and backward direction

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.nref = None
        self.pref = None
        
class Doubly_LL:
    def __init__(self):
        self.head = None
        
    def print_DLL_forward(self):
        if self.head is None:
            print("DLL is empty")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->", end=" ")
                n=n.nref
       
    def print_DLL_backward(self):
        print("\n")
        if self.head is None:
            print("DLL is empty")
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            while n is not None:
                print(n.data,"--->",end=" ")
                n=n.pref
   




DLL= Doubly_LL()
DLL.print_DLL_forward()
DLL.print_DLL_backward()
# Out:
# DLL is empty
#
#
# DLL is empty

# %% [markdown]
# ## Adding a node when DLL is empty

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.nref = None
        self.pref = None
        
class Doubly_LL:
    def __init__(self):
        self.head = None
        
    def print_DLL_forward(self):
        if self.head is None:
            print("DLL is empty")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->", end=" ")
                n=n.nref
       
    def print_DLL_backward(self):
        print("\n")
        if self.head is None:
            print("DLL is empty")
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            while n is not None:
                print(n.data,"--->",end=" ")
                n=n.pref
                
    def add_empty_DLL(self,data):
        if self.head is not None:
            print("DLL is not empty, we cant add node")
        else:
            new_node = Node(data)
            self.head = new_node
      
DLL = Doubly_LL()
DLL.add_empty_DLL(10)
DLL.add_empty_DLL(20)
DLL.print_DLL_forward()
DLL.print_DLL_backward()
# Out:
# DLL is not empty, we cant add node
# 10 --->
#
# 10 --->

# %% [markdown]
# ## Adding a node in DLL at beginning

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.nref = None
        self.pref = None
        
class Doubly_LL:
    def __init__(self):
        self.head = None
        
    def print_DLL_forward(self):
        if self.head is None:
            print("DLL is empty")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->", end=" ")
                n=n.nref
       
    def print_DLL_backward(self):
        print("\n")
        if self.head is None:
            print("DLL is empty")
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            while n is not None:
                print(n.data,"--->",end=" ")
                n=n.pref
            
    def add_begin(self,data):
        new_node =Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n=self.head
            new_node.nref = n
            n.pref = new_node
            self.head = new_node
            
DLL = Doubly_LL()
DLL.add_begin(40)
DLL.add_begin(30)
DLL.add_begin(20)
DLL.print_DLL_forward()
DLL.print_DLL_backward()
# Out:
# 20 ---> 30 ---> 40 --->
#
# 40 ---> 30 ---> 20 --->

# %% [markdown]
# ## Adding a node in DLL at end

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.nref = None
        self.pref = None
        
class Doubly_LL:
    def __init__(self):
        self.head = None
        
    def print_DLL_forward(self):
        if self.head is None:
            print("DLL is empty")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->", end=" ")
                n=n.nref
       
    def print_DLL_backward(self):
        print("\n")
        if self.head is None:
            print("DLL is empty")
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            while n is not None:
                print(n.data,"--->",end=" ")
                n=n.pref
            
    def add_end(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            n.nref = new_node
            new_node.pref = n

DLL = Doubly_LL()
DLL.add_end(40)
DLL.add_end(30)
DLL.add_end(20)
DLL.add_end(60)
DLL.print_DLL_forward()
DLL.print_DLL_backward()
# Out:
# 40 ---> 30 ---> 20 ---> 60 --->
#
# 60 ---> 20 ---> 30 ---> 40 --->

# %% [markdown]
# ## Adding a node in DLL by value after or before node

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.nref = None
        self.pref = None
        
class Doubly_LL:
    def __init__(self):
        self.head = None
        
    def print_DLL_forward(self):
        if self.head is None:
            print("DLL is empty")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->", end=" ")
                n=n.nref
       
    def print_DLL_backward(self):
        print("\n")
        if self.head is None:
            print("DLL is empty")
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            while n is not None:
                print(n.data,"--->",end=" ")
                n=n.pref
                
    def add_empty_DLL(self,data):
        if self.head is not None:
            print("DLL is not empty, we cant add node")
        else:
            new_node = Node(data)
            self.head = new_node
            
    def add_begin(self,data):
        new_node =Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n=self.head
            new_node.nref = n
            n.pref = new_node
            self.head = new_node
            
    def add_end(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            n.nref = new_node
            new_node.pref = n
            
    def add_after(self,data,x):
        if self.head is None:
            print("DLL is empty")
        
        else:
            n = self.head
            while n is not None:
                if x == n.data:
                    break
                n = n.nref
            if n is None:
                print("Given node is not present")
            else:
                new_node = Node(data)
                new_node.nref = n.nref
                new_node.pref = n
                if n.nref is not None:
                    n.nref.pref =new_node
                n.nref = new_node
    
    def add_before(self,data,x):
        if self.head is None:
            print("DLL is empty")
        
        else:
            n = self.head
            while n is not None:
                if x == n.data:
                    break
                n = n.nref
            if n is None:
                print("Given node is not present")
            else:
                new_node = Node(data)
                new_node.nref = n
                new_node.pref = n.pref
                if n.pref is not None:
                    n.pref.nref =new_node
                else:
                    self.head = new_node
                n.pref = new_node
        
        
DLL = Doubly_LL()
DLL.add_begin(40)
DLL.add_begin(30)
DLL.add_begin(20)
DLL.add_end(60)
DLL.add_after(50,40)
DLL.add_before(10,20)
DLL.print_DLL_forward()
DLL.print_DLL_backward()
# Out:
# 20 ---> 30 ---> 40 ---> 60 --->
#
# 60 ---> 40 ---> 30 ---> 20 --->
